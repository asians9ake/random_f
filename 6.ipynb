# %%
import numpy as np 
import matplotlib.pyplot as plt 
from scipy.fftpack import fft2, fftshift


l = plt.imread('cancercell.jpg').astype(float)
f1 = np.fft.fft2(l)

f2 = np.fft.fftshift(f1)
 
plt.subplot(2, 2, 1)
plt.imshow(np.abs(f1), cmap='gray')
plt.title('Frequency Spectrum')

 
plt.subplot(2, 2, 2)
plt.imshow(np.abs(f2), cmap='gray')
plt.title('Centered Spectrum')

 
f3 = np.log(1 + np.abs(f2))


plt.subplot(2, 2, 3)
plt.imshow(f3, cmap='gray')
plt.title('log(1+abs(f2))')


l_fft = np.fft.ifft2(f1)
l1 = np.real(l_fft)


plt.subplot(2, 2, 4)
plt.imshow(l1, cmap='gray')
plt.title('Inverse 2-D FFT')


plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [1.5765166949677223e-14..253152.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [1.5765166949677223e-14..253152.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [1.57651669496771e-14..12.441749328009251].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-6.218767191609766e-14..255.00000000000014].
